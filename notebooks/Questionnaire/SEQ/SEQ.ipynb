# %% [markdown]
# # Single Ease Question (SEQ)

# %%
import pandas as pd

# Define the relative path to the CSV file
file_path = "../../../cleaned_data/questionnaire_df.csv"

questionnaire_df = pd.read_csv(file_path)

# Filter columns that contain "PERSONAL" or "SEQ" in their names
filtered_columns = [col for col in questionnaire_df.columns if "Controller" in col or "SEQ" in col or "participant_code" in col]

# Create a new dataframe with the filtered columns
filtered_df = questionnaire_df[filtered_columns]

# Display the new dataframe
filtered_df.head()
# Out:
#   PERSONAL_Controller being tested? PERSONAL_participant_code  \
# 0                            Chiron                    HASJ22
# 1                            Chiron                    AAHF21
# 2                            Chiron                    DOCS21
# 3                            Chiron                    ATSF08
# 4                            Chiron                    CEEJ05
#
#    SIM-WITH-VR_(SEQ) Overall, how easy or difficult did you find to perform this task?  \
# 0                                                  4
# 1                                                  7
# 2                                                  3
# 3                                                  6
# 4                                                  5
#
#    SIM-NO-VR_(SEQ) Overall, how easy or difficult did you find to perform this task?.1  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  6
#
#    RW-WITH-VR_(TASK 1) (SEQ) Overall, how easy or difficult did you find to perform this task?  \
# 0                                                  6
# 1                                                  6
# 2                                                  5
# 3                                                  3
# 4                                                  6
#
#    RW-WITH-VR_(TASK 2) (SEQ) Overall, how easy or difficult did you find to perform this task?  \
# 0                                                5.0
# 1                                                5.0
# 2                                                4.0
# 3                                                2.0
# 4                                                5.0
#
#    RW-WITH-VR_(TASK 3) (SEQ) Overall, how easy or difficult did you find to perform this task?  \
# 0                                                4.0
# 1                                                4.0
# 2                                                3.0
# 3                                                4.0
# 4                                                4.0
#
#    RW-NO-VR_(TASK 1) (SEQ) Overall, how easy or difficult did you find to perform this task?.1  \
# 0                                                  4
# 1                                                  2
# 2                                                  2
# 3                                                  4
# 4                                                  3
#
#    RW-NO-VR_(TASK 2) (SEQ) Overall, how easy or difficult did you find to perform this task?.1  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    RW-NO-VR_(TASK 3) (SEQ) Overall, how easy or difficult did you find to perform this task?.1
# 0                                                3.0
# 1                                                3.0
# 2                                                2.0
# 3                                                3.0
# 4                                                2.0

# %%
import pandas as pd

# Extract relevant columns
selected_columns = filtered_df.iloc[:, :10]  # Assuming the first 9 columns are relevant

# Rename columns as per the specified format
selected_columns.columns = [
    "Controller",
    "ID",
    "SIM-WITH-VR",
    "SIM-NO-VR",
    "RW-WITH-VR-1",
    "RW-WITH-VR-2",
    "RW-WITH-VR-3",
    "RW-NO-VR-1",
    "RW-NO-VR-2",
    "RW-NO-VR-3"
]

selected_columns["Controller"] = selected_columns["Controller"].replace("Chiron", "SBC")
selected_columns.to_csv("seq.csv", index=False)
selected_columns
# Out:
#    Controller      ID  SIM-WITH-VR  SIM-NO-VR  RW-WITH-VR-1  RW-WITH-VR-2  \
# 0         SBC  HASJ22            4          5             6           5.0
# 1         SBC  AAHF21            7          5             6           5.0
# 2         SBC  DOCS21            3          5             5           4.0
# 3         SBC  ATSF08            6          4             3           2.0
# 4         SBC  CEEJ05            5          6             6           5.0
# 5         SBC  NULS22            5          2             6           4.0
# 6         SBC  DAMA12            6          5             3           3.0
# 7         SBC  XHKB15            5          4             4           4.0
# 8         SBC  RENL05            5          3             6           5.0
# 9         WBC  ARAH22            3          6             4           3.0
# 10        WBC  BTHH23            3          5             6           6.0
# 11        WBC  ELBH19            5          6             7           7.0
# 12        WBC  LEMT02            5          4             3           3.0
# 13        WBC  MGNH15            4          1             2           1.0
# 14        WBC  DOFS27            6          4             3           3.0
# 15        WBC  IICM04            4          3             7           7.0
# 16        WBC  REKD03            7          6             5           4.0
# 17        WBC  NRKH02            5          3             4           4.0
# 18        WBC  SASD12            6          5             6           3.0
# 19        SBC  EECW29            4          2             3           2.0
#
#     RW-WITH-VR-3  RW-NO-VR-1  RW-NO-VR-2  RW-NO-VR-3
# 0            4.0           4           3         3.0
# 1            4.0           2           3         3.0
# 2            3.0           2           2         2.0
# 3            4.0           4           3         3.0
# 4            4.0           3           3         2.0
# 5            3.0           6           2         3.0
# 6            3.0           3           3         2.0
# 7            3.0           2           2         2.0
# 8            3.0           3           2         2.0
# 9            2.0           4           2         2.0
# 10           3.0           2           2         1.0
# 11           6.0           3           2         2.0
# 12           2.0           2           2         1.0
# 13           2.0           3           1         1.0
# 14           3.0           2           2         3.0
# 15           6.0           2           1         2.0
# 16           3.0           2           2         2.0
# 17           3.0           3           2         2.0
# 18           5.0           3           2         3.0
# 19           3.0           2           2         1.0

# %%
# Separate statistics for each controller (SBC and WBC)
sbc_stats = selected_columns[selected_columns["Controller"] == "SBC"].iloc[:, 1:].agg(["mean", "median", "std", "min", "max"])
wbc_stats = selected_columns[selected_columns["Controller"] == "WBC"].iloc[:, 1:].agg(["mean", "median", "std", "min", "max"])

# %%
sbc_stats
# Out:
#         SIM-WITH-VR  SIM-NO-VR  RW-WITH-VR-1  RW-WITH-VR-2  RW-WITH-VR-3  \
# mean       5.000000    4.10000      4.800000      3.900000      3.400000
# median     5.000000    4.50000      5.500000      4.000000      3.000000
# std        1.154701    1.37032      1.398412      1.197219      0.516398
# min        3.000000    2.00000      3.000000      2.000000      3.000000
# max        7.000000    6.00000      6.000000      5.000000      4.000000
#
#         RW-NO-VR-1  RW-NO-VR-2  RW-NO-VR-3
# mean      3.100000    2.500000    2.300000
# median    3.000000    2.500000    2.000000
# std       1.286684    0.527046    0.674949
# min       2.000000    2.000000    1.000000
# max       6.000000    3.000000    3.000000

# %%
wbc_stats
# Out:
#         SIM-WITH-VR  SIM-NO-VR  RW-WITH-VR-1  RW-WITH-VR-2  RW-WITH-VR-3  \
# mean       4.800000   4.300000      4.700000      4.100000      3.500000
# median     5.000000   4.500000      4.500000      3.500000      3.000000
# std        1.316561   1.636392      1.766981      1.969207      1.581139
# min        3.000000   1.000000      2.000000      1.000000      2.000000
# max        7.000000   6.000000      7.000000      7.000000      6.000000
#
#         RW-NO-VR-1  RW-NO-VR-2  RW-NO-VR-3
# mean      2.600000    1.800000    1.900000
# median    2.500000    2.000000    2.000000
# std       0.699206    0.421637    0.737865
# min       2.000000    1.000000    1.000000
# max       4.000000    2.000000    3.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Extract mean values for each controller
sbc_means = sbc_stats.loc["mean"]
wbc_means = wbc_stats.loc["mean"]

# Create a new DataFrame for plotting
mean_df = pd.DataFrame({
    "Trial": [1, 2, 3] * 4,
    "Mean Score": [
        sbc_means["RW-WITH-VR-1"], sbc_means["RW-WITH-VR-2"], sbc_means["RW-WITH-VR-3"],
        sbc_means["RW-NO-VR-1"], sbc_means["RW-NO-VR-2"], sbc_means["RW-NO-VR-3"],
        wbc_means["RW-WITH-VR-1"], wbc_means["RW-WITH-VR-2"], wbc_means["RW-WITH-VR-3"],
        wbc_means["RW-NO-VR-1"], wbc_means["RW-NO-VR-2"], wbc_means["RW-NO-VR-3"]
    ],
    "Condition": [
        "SBC with VR", "SBC with VR", "SBC with VR",
        "SBC without VR", "SBC without VR", "SBC without VR",
        "WBC with VR", "WBC with VR", "WBC with VR",
        "WBC without VR", "WBC without VR", "WBC without VR"
    ]
})

# Define colors and markers
color_map = {"SBC with VR": "skyblue", "SBC without VR": "salmon", "WBC with VR": "skyblue", "WBC without VR": "salmon"}
marker_map = {"SBC with VR": "o", "SBC without VR": "o", "WBC with VR": "s", "WBC without VR": "s"}  # Squares for WBC

# Create the plot
plt.figure(figsize=(8, 4))
ax = sns.lineplot(data=mean_df, x="Trial", y="Mean Score", hue="Condition", style="Condition",
                  markers=marker_map, palette=color_map, linewidth=2, markersize=8)

# Apply the line styles (solid for SBC, dashed for WBC)
for line, label in zip(ax.lines, mean_df["Condition"].unique()):
    if "WBC" in label:
        line.set_linestyle("--")  # Dashed line for WBC
    else:
        line.set_linestyle("-")  # Solid line for SBC
        
# Adjust legend and labels
plt.xticks([1, 2, 3]) 
plt.yticks(range(1, 8))  # Set y-axis scale from 1 to 7
plt.ylim(1, 7)  # Ensure the y-axis is limited from 1 to 7
plt.legend(title="Condition")
plt.xlabel("Trial Number")
plt.ylabel("Mean Score")
plt.title("Mean SEQ scores per Trial")
plt.tight_layout()
plt.savefig("mean_seq_trials_rw.pdf", format='pdf')

# Show plot
plt.show()

# %% [markdown]
# # Reverse thescale to compare to benchmark

# %%
import pandas as pd

seq_df = selected_columns

# Make a copy of the original dataframe to preserve 'selected_columns'
seq_reversed_df = seq_df.copy()

# Identify numeric columns that need to be reversed
numeric_columns = seq_reversed_df.select_dtypes(include=['number']).columns

# Reverse the SEQ scale for all numeric columns (assuming scale is from 1 to 7)
seq_reversed_df[numeric_columns] = 8 - seq_reversed_df[numeric_columns]

# Save the modified dataframe to a new CSV file
seq_reversed_df.to_csv("seq.csv", index=False)

# Display the first few rows of the reversed dataframe
print(seq_reversed_df.head())
# Out:
#   Controller      ID  SIM-WITH-VR  SIM-NO-VR  RW-WITH-VR-1  RW-WITH-VR-2  \
# 0        SBC  HASJ22            4          3             2           3.0
# 1        SBC  AAHF21            1          3             2           3.0
# 2        SBC  DOCS21            5          3             3           4.0
# 3        SBC  ATSF08            2          4             5           6.0
# 4        SBC  CEEJ05            3          2             2           3.0
#
#    RW-WITH-VR-3  RW-NO-VR-1  RW-NO-VR-2  RW-NO-VR-3
# 0           4.0           4           5         5.0
# 1           4.0           6           5         5.0
# 2           5.0           6           6         6.0
# 3           4.0           4           5         5.0
# 4           4.0           5           5         6.0

# %%
seq_reversed_df
# Out:
#    Controller  SIM-WITH-VR  SIM-NO-VR  RW-WITH-VR-1  RW-WITH-VR-2  \
# 0         SBC            4          3             2           3.0
# 1         SBC            1          3             2           3.0
# 2         SBC            5          3             3           4.0
# 3         SBC            2          4             5           6.0
# 4         SBC            3          2             2           3.0
# 5         SBC            3          6             2           4.0
# 6         SBC            2          3             5           5.0
# 7         SBC            3          4             4           4.0
# 8         SBC            3          5             2           3.0
# 9         WBC            5          2             4           5.0
# 10        WBC            5          3             2           2.0
# 11        WBC            3          2             1           1.0
# 12        WBC            3          4             5           5.0
# 13        WBC            4          7             6           7.0
# 14        WBC            2          4             5           5.0
# 15        WBC            4          5             1           1.0
# 16        WBC            1          2             3           4.0
# 17        WBC            3          5             4           4.0
# 18        WBC            2          3             2           5.0
# 19        SBC            4          6             5           6.0
#
#     RW-WITH-VR-3  RW-NO-VR-1  RW-NO-VR-2  RW-NO-VR-3
# 0            4.0           4           5         5.0
# 1            4.0           6           5         5.0
# 2            5.0           6           6         6.0
# 3            4.0           4           5         5.0
# 4            4.0           5           5         6.0
# 5            5.0           2           6         5.0
# 6            5.0           5           5         6.0
# 7            5.0           6           6         6.0
# 8            5.0           5           6         6.0
# 9            6.0           4           6         6.0
# 10           5.0           6           6         7.0
# 11           2.0           5           6         6.0
# 12           6.0           6           6         7.0
# 13           6.0           5           7         7.0
# 14           5.0           6           6         5.0
# 15           2.0           6           7         6.0
# 16           5.0           6           6         6.0
# 17           5.0           5           6         6.0
# 18           3.0           5           6         5.0
# 19           5.0           6           6         7.0

# %%
# Separate statistics for each controller (SBC and WBC)
sbc_stats = seq_reversed_df[seq_reversed_df["Controller"] == "SBC"].iloc[:, 1:].agg(["mean", "median", "std", "min", "max"])
wbc_stats = seq_reversed_df[seq_reversed_df["Controller"] == "WBC"].iloc[:, 1:].agg(["mean", "median", "std", "min", "max"])

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Extract mean values for each controller
sbc_means = sbc_stats.loc["mean"]
wbc_means = wbc_stats.loc["mean"]

# Create a new DataFrame for plotting
mean_df = pd.DataFrame({
    "Trial": [1, 2, 3] * 4,
    "Mean Score": [
        sbc_means["RW-WITH-VR-1"], sbc_means["RW-WITH-VR-2"], sbc_means["RW-WITH-VR-3"],
        sbc_means["RW-NO-VR-1"], sbc_means["RW-NO-VR-2"], sbc_means["RW-NO-VR-3"],
        wbc_means["RW-WITH-VR-1"], wbc_means["RW-WITH-VR-2"], wbc_means["RW-WITH-VR-3"],
        wbc_means["RW-NO-VR-1"], wbc_means["RW-NO-VR-2"], wbc_means["RW-NO-VR-3"]
    ],
    "Condition": [
        "SBC with VR", "SBC with VR", "SBC with VR",
        "SBC without VR", "SBC without VR", "SBC without VR",
        "WBC with VR", "WBC with VR", "WBC with VR",
        "WBC without VR", "WBC without VR", "WBC without VR"
    ]
})

# Define colors and markers
color_map = {"SBC with VR": "skyblue", "SBC without VR": "salmon", "WBC with VR": "skyblue", "WBC without VR": "salmon"}
marker_map = {"SBC with VR": "o", "SBC without VR": "o", "WBC with VR": "s", "WBC without VR": "s"}  # Squares for WBC

# Create the plot
plt.figure(figsize=(8, 4))
ax = sns.lineplot(data=mean_df, x="Trial", y="Mean Score", hue="Condition", style="Condition",
                  markers=marker_map, palette=color_map, linewidth=2, markersize=8)

# Apply the line styles (solid for SBC, dashed for WBC)
for line, label in zip(ax.lines, mean_df["Condition"].unique()):
    if "WBC" in label:
        line.set_linestyle("--")  # Dashed line for WBC
    else:
        line.set_linestyle("-")  # Solid line for SBC
        
# Adjust legend and labels
plt.xticks([1, 2, 3]) 
plt.yticks(range(1, 8))  # Set y-axis scale from 1 to 7
plt.ylim(1, 7)  # Ensure the y-axis is limited from 1 to 7
plt.legend(title="Condition")
plt.xlabel("Trial Number")
plt.ylabel("Mean Score")
plt.title("Mean SEQ scores per Trial")
plt.tight_layout()
plt.savefig("mean_seq_trials_rw.pdf", format='pdf')

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the means for each requested condition
mean_sim_with_vr_wbc = wbc_stats.loc["mean", "SIM-WITH-VR"]
mean_sim_with_vr_sbc = sbc_stats.loc["mean", "SIM-WITH-VR"]
mean_rw_with_vr_wbc = wbc_stats.loc["mean", ["RW-WITH-VR-1", "RW-WITH-VR-2", "RW-WITH-VR-3"]].mean()
mean_rw_with_vr_sbc = sbc_stats.loc["mean", ["RW-WITH-VR-1", "RW-WITH-VR-2", "RW-WITH-VR-3"]].mean()

mean_sim_no_vr_wbc = wbc_stats.loc["mean", "SIM-NO-VR"]
mean_sim_no_vr_sbc = sbc_stats.loc["mean", "SIM-NO-VR"]
mean_rw_no_vr_wbc = wbc_stats.loc["mean", ["RW-NO-VR-1", "RW-NO-VR-2", "RW-NO-VR-3"]].mean()
mean_rw_no_vr_sbc = sbc_stats.loc["mean", ["RW-NO-VR-1", "RW-NO-VR-2", "RW-NO-VR-3"]].mean()

# Create a DataFrame for plotting
plot_data = {
    "Condition": ["With VR", "With VR", "With VR", "With VR", "Without VR", "Without VR", "Without VR", "Without VR"],
    "Controller": ["WBC SIM", "SBC SIM", "WBC RW", "SBC RW", "WBC SIM", "SBC SIM", "WBC RW", "SBC RW"],
    "Mean Score": [
        mean_sim_with_vr_wbc, mean_sim_with_vr_sbc, mean_rw_with_vr_wbc, mean_rw_with_vr_sbc,
        mean_sim_no_vr_wbc, mean_sim_no_vr_sbc, mean_rw_no_vr_wbc, mean_rw_no_vr_sbc
    ]
}

plot_df = pd.DataFrame(plot_data)

# Add 'SIM' or 'RW' for the Condition Type
plot_df["Condition Type"] = plot_df["Controller"].apply(lambda x: "SIM" if "SIM" in x else "RW")


# Create the barplot with specified hue order
plt.figure(figsize=(7, 4))
ax = sns.barplot(x="Condition", y="Mean Score", hue="Controller", data=plot_df, 
                palette=["mediumspringgreen", "mediumspringgreen", "gold", "gold"] * 2) #Repeat for both conditions

# Apply hatching for WBC (Corrected and Simplified)
for i, patch in enumerate(ax.patches):
    if i == 0:
        patch.set_hatch("//")
    if i == 1:
        patch.set_hatch("//")
    if i == 4:
        patch.set_hatch("//")
    if i == 5:
        patch.set_hatch("//")
    if i==8:
        patch.set_hatch("//")
    if i==10:
        patch.set_hatch("//")

# Customize the plot
plt.title("Mean SEQ usability scores in Simulation (SIM) and in the Real World (RW)")
plt.xlabel("Modality")
plt.ylabel("Mean Score")
plt.xticks(rotation=0)
plt.ylim(1, 7)  # Set scale from 1 to 7
plt.legend(title="Controller and Condition", loc="upper left")

plt.tight_layout()
output_path = "mean_SEQ_sim_rw.pdf"  # Specify your desired file path
plt.savefig(output_path, format='pdf')
# Show plot
plt.show()
# Out:
# <ipython-input-12-75d09fc3f77e>:34: UserWarning: The palette list has more values (8) than needed (4), which may not be intended.
#   ax = sns.barplot(x="Condition", y="Mean Score", hue="Controller", data=plot_df,

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np


# Function to extract the first number from a string and convert it to an integer
def extract_first_number(cell):
    match = re.match(r"(\d+)", str(cell))  # Extract the first number
    return int(match.group(1)) if match else None  # Convert to int

# Apply the function to all columns except 'Controller'
columns_to_clean = [col for col in df.columns if col != "Controller"]
df[columns_to_clean] = df[columns_to_clean].applymap(extract_first_number)

# Compute the required statistics for each controller
stats_df = df.groupby("Controller")[columns_to_clean].agg(
    ["mean", "std", "median", "min", "max", "count"]
)

# Flatten MultiIndex columns
stats_df.columns = ['_'.join(col).strip() for col in stats_df.columns.values]

# Transpose DataFrame for structured analysis
stats_df_transposed = stats_df.T

# Function to compute standard error of the mean (SEM)
def compute_sem(std, count):
    return std / np.sqrt(count)

# Corrected color palette size
palette_colors = ["mediumspringgreen", "mediumspringgreen", "gold", "gold"]

# Create a DataFrame for plotting
plot_df = pd.DataFrame({
    "Condition": ["With VR", "With VR", "With VR", "With VR", "Without VR", "Without VR", "Without VR", "Without VR"],
    "Controller": ["WBC SIM", "SBC SIM", "WBC RW", "SBC RW", "WBC SIM", "SBC SIM", "WBC RW", "SBC RW"],
    "Mean Score": [
        stats_df_transposed.loc["SIM-WITH-VR_mean", "WBC"],
        stats_df_transposed.loc["SIM-WITH-VR_mean", "SBC"],
        stats_df_transposed.loc[["RW-WITH-VR-1_mean", "RW-WITH-VR-2_mean", "RW-WITH-VR-3_mean"], "WBC"].mean(),
        stats_df_transposed.loc[["RW-WITH-VR-1_mean", "RW-WITH-VR-2_mean", "RW-WITH-VR-3_mean"], "SBC"].mean(),
        stats_df_transposed.loc["SIM-NO-VR_mean", "WBC"],
        stats_df_transposed.loc["SIM-NO-VR_mean", "SBC"],
        stats_df_transposed.loc[["RW-NO-VR-1_mean", "RW-NO-VR-2_mean", "RW-NO-VR-3_mean"], "WBC"].mean(),
        stats_df_transposed.loc[["RW-NO-VR-1_mean", "RW-NO-VR-2_mean", "RW-NO-VR-3_mean"], "SBC"].mean()
    ],
    "SEM": [
        compute_sem(stats_df_transposed.loc["SIM-WITH-VR_std", "WBC"], stats_df_transposed.loc["SIM-WITH-VR_count", "WBC"]),
        compute_sem(stats_df_transposed.loc["SIM-WITH-VR_std", "SBC"], stats_df_transposed.loc["SIM-WITH-VR_count", "SBC"]),
        compute_sem(stats_df_transposed.loc[["RW-WITH-VR-1_std", "RW-WITH-VR-2_std", "RW-WITH-VR-3_std"], "WBC"].mean(), stats_df_transposed.loc[["RW-WITH-VR-1_count", "RW-WITH-VR-2_count", "RW-WITH-VR-3_count"], "WBC"].sum()),
        compute_sem(stats_df_transposed.loc[["RW-WITH-VR-1_std", "RW-WITH-VR-2_std", "RW-WITH-VR-3_std"], "SBC"].mean(), stats_df_transposed.loc[["RW-WITH-VR-1_count", "RW-WITH-VR-2_count", "RW-WITH-VR-3_count"], "SBC"].sum()),
        compute_sem(stats_df_transposed.loc["SIM-NO-VR_std", "WBC"], stats_df_transposed.loc["SIM-NO-VR_count", "WBC"]),
        compute_sem(stats_df_transposed.loc["SIM-NO-VR_std", "SBC"], stats_df_transposed.loc["SIM-NO-VR_count", "SBC"]),
        compute_sem(stats_df_transposed.loc[["RW-NO-VR-1_std", "RW-NO-VR-2_std", "RW-NO-VR-3_std"], "WBC"].mean(), stats_df_transposed.loc[["RW-NO-VR-1_count", "RW-NO-VR-2_count", "RW-NO-VR-3_count"], "WBC"].sum()),
        compute_sem(stats_df_transposed.loc[["RW-NO-VR-1_std", "RW-NO-VR-2_std", "RW-NO-VR-3_std"], "SBC"].mean(), stats_df_transposed.loc[["RW-NO-VR-1_count", "RW-NO-VR-2_count", "RW-NO-VR-3_count"], "SBC"].sum())
    ]
})

# Create the barplot with SEM error bars
plt.figure(figsize=(7, 4))
ax = sns.barplot(
    x="Condition", y="Mean Score", hue="Controller", data=plot_df,
    palette=palette_colors, errorbar=None
)

        
# Add error bars manually for each patch
for i, patch in enumerate(ax.patches):
    if i<8:
        mean = plot_df.iloc[i]["Mean Score"]
        sem = plot_df.iloc[i]["SEM"]
        x = patch.get_x() + patch.get_width() / 2  # Center error bars correctly
        y = patch.get_height()  # Align error bars to top of the bar
        ax.errorbar(x, y, yerr=sem, fmt='none', ecolor='black', capsize=5)

# Apply hatching for WBC bars
for i, patch in enumerate(ax.patches):
    if i in [0, 1, 4, 5,8,10]:
        patch.set_hatch("//")

# Customize the plot
plt.title("Mean SEQ Scores in Simulation (SIM) and Real World (RW)")
plt.xlabel("Modality")
plt.ylabel("Mean Score")
plt.xticks(rotation=0)
plt.ylim(1, 7)  # Set scale from 1 to 7
plt.legend(title="Controller and Condition", loc="upper left")

plt.tight_layout()
output_path = "mean_SEQ_sim_rw.pdf"  # Specify your desired file path
#plt.savefig(output_path, format='pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-88744acde4bf> in <module>
#      12
#      13 # Apply the function to all columns except 'Controller'
# ---> 14 columns_to_clean = [col for col in df.columns if col != "Controller"]
#      15 df[columns_to_clean] = df[columns_to_clean].applymap(extract_first_number)
#      16
#
# NameError: name 'df' is not defined
